# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urldefrag
from collections import deque
from pathlib import Path

# %%
BASE = "https://docs.manim.community/en/stable/"
OUTPUT_DIR = "page_content"

# %%
def link_to_file_name(link):
    return link[39:].replace('/', '.')

# %%
def is_html_doc(link: str) -> bool:
    if not link.startswith(BASE):
        return False
    if link.endswith((".png", ".jpg", ".svg", ".gif", ".pdf", ".json", ".js", ".css")):
        return False
    if any(x in link for x in ("/_sources/", "#", "genindex", "search", "py-modindex")):
        return False
    return True

# %%
session = requests.Session()
visited = set()
queue = deque([BASE])

while queue:
    url = queue.popleft()

    if url in visited:
        continue

    visited.add(url)
    print(f"[visited] {url}")

    try:
        response = session.get(url, timeout=15)
        response.raise_for_status()
    except requests.RequestException as exc:
        print(f"[skip] {url} — {exc}")
        continue

    # Add content
    if link_to_file_name(url):
        with open(f"{OUTPUT_DIR}/{link_to_file_name(url)}", "wb") as f:
            # Put url at the front
            url_line = (url + "\n").encode('utf-8') 
            f.write(url_line)
            f.write(response.content)
    else:
        print("[skip] root")

    # Travel through internal links
    for a in BeautifulSoup(response.text, "html.parser").find_all("a", href=True):
        link, _ = urldefrag(urljoin(url, a["href"]))
        if is_html_doc(link) and link not in visited:
            queue.append(link)
# Out:
# [visited] https://docs.manim.community/en/stable/
# [skip] root
# [visited] https://docs.manim.community/en/stable/examples.html
# [visited] https://docs.manim.community/en/stable/installation.html
# [visited] https://docs.manim.community/en/stable/installation/uv.html
# [visited] https://docs.manim.community/en/stable/installation/conda.html
# [visited] https://docs.manim.community/en/stable/installation/docker.html
# [visited] https://docs.manim.community/en/stable/installation/jupyter.html
# [visited] https://docs.manim.community/en/stable/tutorials_guides.html
# [visited] https://docs.manim.community/en/stable/tutorials/index.html
# [visited] https://docs.manim.community/en/stable/tutorials/quickstart.html
# [visited] https://docs.manim.community/en/stable/tutorials/output_and_config.html
# [visited] https://docs.manim.community/en/stable/tutorials/building_blocks.html
# [visited] https://docs.manim.community/en/stable/guides/index.html
# [visited] https://docs.manim.community/en/stable/guides/configuration.html
# [visited] https://docs.manim.community/en/stable/guides/deep_dive.html
# [visited] https://docs.manim.community/en/stable/guides/using_text.html
# [visited] https://docs.manim.community/en/stable/guides/add_voiceovers.html
# [visited] https://docs.manim.community/en/stable/faq/index.html
# [visited] https://docs.manim.community/en/stable/faq/general.html
# [visited] https://docs.manim.community/en/stable/faq/help.html
# [visited] https://docs.manim.community/en/stable/faq/installation.html
# [visited] https://docs.manim.community/en/stable/faq/internals.html
# [visited] https://docs.manim.community/en/stable/faq/opengl.html
# [visited] https://docs.manim.community/en/stable/reference.html
# [visited] https://docs.manim.community/en/stable/reference_index/animations.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.animation.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.animation.Add.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.animation.Animation.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.animation.Wait.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.changing.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.changing.AnimatedBoundary.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.changing.TracedPath.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.composition.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.composition.AnimationGroup.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.composition.LaggedStart.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.composition.LaggedStartMap.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.composition.Succession.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.creation.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.creation.AddTextLetterByLetter.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.creation.AddTextWordByWord.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.creation.Create.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.creation.DrawBorderThenFill.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.creation.RemoveTextLetterByLetter.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.creation.ShowIncreasingSubsets.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.creation.ShowPartial.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.creation.ShowSubmobjectsOneByOne.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.creation.SpiralIn.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.creation.TypeWithCursor.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.creation.Uncreate.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.creation.UntypeWithCursor.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.creation.Unwrite.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.creation.Write.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.fading.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.fading.FadeIn.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.fading.FadeOut.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.growing.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.growing.GrowArrow.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.growing.GrowFromCenter.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.growing.GrowFromEdge.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.growing.GrowFromPoint.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.growing.SpinInFromNothing.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.indication.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.indication.ApplyWave.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.indication.Blink.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.indication.Circumscribe.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.indication.Flash.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.indication.FocusOn.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.indication.Indicate.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.indication.ShowPassingFlash.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.indication.ShowPassingFlashWithThinningStrokeWidth.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.indication.Wiggle.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.movement.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.movement.ComplexHomotopy.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.movement.Homotopy.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.movement.MoveAlongPath.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.movement.PhaseFlow.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.movement.SmoothedVectorizedHomotopy.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.numbers.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.numbers.ChangeDecimalToValue.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.numbers.ChangingDecimal.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.rotation.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.rotation.Rotate.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.rotation.Rotating.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.specialized.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.specialized.Broadcast.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.speedmodifier.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.speedmodifier.ChangeSpeed.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.transform.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.transform.ApplyComplexFunction.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.transform.ApplyFunction.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.transform.ApplyMatrix.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.transform.ApplyMethod.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.transform.ApplyPointwiseFunction.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.transform.ApplyPointwiseFunctionToCenter.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.transform.ClockwiseTransform.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.transform.CounterclockwiseTransform.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.transform.CyclicReplace.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.transform.FadeToColor.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.transform.FadeTransform.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.transform.FadeTransformPieces.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.transform.MoveToTarget.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.transform.ReplacementTransform.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.transform.Restore.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.transform.ScaleInPlace.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.transform.ShrinkToCenter.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.transform.Swap.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.transform.Transform.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.transform.TransformAnimations.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.transform.TransformFromCopy.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.transform_matching_parts.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.transform_matching_parts.TransformMatchingAbstractBase.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.transform_matching_parts.TransformMatchingShapes.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.transform_matching_parts.TransformMatchingTex.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.updaters.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.updaters.mobject_update_utils.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.updaters.update.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.updaters.update.MaintainPositionRelativeTo.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.updaters.update.UpdateFromAlphaFunc.html
# [visited] https://docs.manim.community/en/stable/reference/manim.animation.updaters.update.UpdateFromFunc.html
# [visited] https://docs.manim.community/en/stable/reference_index/cameras.html
# [visited] https://docs.manim.community/en/stable/reference/manim.camera.camera.html
# [visited] https://docs.manim.community/en/stable/reference/manim.camera.camera.BackgroundColoredVMobjectDisplayer.html
# [visited] https://docs.manim.community/en/stable/reference/manim.camera.camera.Camera.html
# [visited] https://docs.manim.community/en/stable/reference/manim.camera.mapping_camera.html
# [visited] https://docs.manim.community/en/stable/reference/manim.camera.mapping_camera.MappingCamera.html
# [visited] https://docs.manim.community/en/stable/reference/manim.camera.mapping_camera.OldMultiCamera.html
# [visited] https://docs.manim.community/en/stable/reference/manim.camera.mapping_camera.SplitScreenCamera.html
# [visited] https://docs.manim.community/en/stable/reference/manim.camera.moving_camera.html
# [visited] https://docs.manim.community/en/stable/reference/manim.camera.moving_camera.MovingCamera.html
# [visited] https://docs.manim.community/en/stable/reference/manim.camera.multi_camera.html
# [visited] https://docs.manim.community/en/stable/reference/manim.camera.multi_camera.MultiCamera.html
# [visited] https://docs.manim.community/en/stable/reference/manim.camera.three_d_camera.html
# [visited] https://docs.manim.community/en/stable/reference/manim.camera.three_d_camera.ThreeDCamera.html
# [visited] https://docs.manim.community/en/stable/reference_index/configuration.html
# [visited] https://docs.manim.community/en/stable/reference/manim._config.html
# [visited] https://docs.manim.community/en/stable/reference/manim._config.utils.html
# [visited] https://docs.manim.community/en/stable/reference/manim._config.utils.ManimConfig.html
# [visited] https://docs.manim.community/en/stable/reference/manim._config.utils.ManimFrame.html
# [visited] https://docs.manim.community/en/stable/reference/manim._config.logger_utils.html
# [visited] https://docs.manim.community/en/stable/reference/manim._config.logger_utils.JSONFormatter.html
# [visited] https://docs.manim.community/en/stable/reference_index/mobjects.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.frame.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.frame.FullScreenRectangle.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.frame.ScreenRectangle.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.arc.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.arc.AnnotationDot.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.arc.AnnularSector.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.arc.Annulus.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.arc.Arc.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.arc.ArcBetweenPoints.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.arc.ArcPolygon.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.arc.ArcPolygonFromArcs.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.arc.Circle.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.arc.CubicBezier.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.arc.CurvedArrow.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.arc.CurvedDoubleArrow.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.arc.Dot.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.arc.Ellipse.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.arc.LabeledDot.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.arc.Sector.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.arc.TipableVMobject.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.boolean_ops.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.boolean_ops.Difference.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.boolean_ops.Exclusion.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.boolean_ops.Intersection.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.boolean_ops.Union.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.labeled.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.labeled.Label.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.labeled.LabeledArrow.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.labeled.LabeledLine.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.labeled.LabeledPolygram.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.line.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.line.Angle.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.line.Arrow.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.line.DashedLine.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.line.DoubleArrow.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.line.Elbow.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.line.Line.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.line.RightAngle.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.line.TangentLine.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.line.Vector.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.polygram.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.polygram.ConvexHull.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.polygram.Cutout.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.polygram.Polygon.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.polygram.Polygram.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.polygram.Rectangle.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.polygram.RegularPolygon.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.polygram.RegularPolygram.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.polygram.RoundedRectangle.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.polygram.Square.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.polygram.Star.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.polygram.Triangle.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.shape_matchers.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.shape_matchers.BackgroundRectangle.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.shape_matchers.Cross.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.shape_matchers.SurroundingRectangle.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.shape_matchers.Underline.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.tips.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.tips.ArrowCircleFilledTip.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.tips.ArrowCircleTip.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.tips.ArrowSquareFilledTip.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.tips.ArrowSquareTip.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.tips.ArrowTip.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.tips.ArrowTriangleFilledTip.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.tips.ArrowTriangleTip.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.geometry.tips.StealthTip.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.graph.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.graph.DiGraph.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.graph.GenericGraph.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.graph.Graph.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.graph.LayoutFunction.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.graphing.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.graphing.coordinate_systems.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.graphing.coordinate_systems.Axes.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.graphing.coordinate_systems.ComplexPlane.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.graphing.coordinate_systems.CoordinateSystem.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.graphing.coordinate_systems.NumberPlane.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.graphing.coordinate_systems.PolarPlane.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.graphing.coordinate_systems.ThreeDAxes.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.graphing.functions.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.graphing.functions.FunctionGraph.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.graphing.functions.ImplicitFunction.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.graphing.functions.ParametricFunction.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.graphing.number_line.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.graphing.number_line.NumberLine.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.graphing.number_line.UnitInterval.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.graphing.probability.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.graphing.probability.BarChart.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.graphing.probability.SampleSpace.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.graphing.scale.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.graphing.scale.LinearBase.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.graphing.scale.LogBase.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.logo.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.logo.ManimBanner.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.matrix.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.matrix.DecimalMatrix.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.matrix.IntegerMatrix.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.matrix.Matrix.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.matrix.MobjectMatrix.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.mobject.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.mobject.Group.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.mobject.Mobject.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.svg.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.svg.brace.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.svg.brace.ArcBrace.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.svg.brace.Brace.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.svg.brace.BraceBetweenPoints.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.svg.brace.BraceLabel.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.svg.brace.BraceText.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.svg.svg_mobject.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.svg.svg_mobject.SVGMobject.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.svg.svg_mobject.VMobjectFromSVGPath.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.table.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.table.DecimalTable.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.table.IntegerTable.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.table.MathTable.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.table.MobjectTable.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.table.Table.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.text.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.text.code_mobject.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.text.code_mobject.Code.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.text.numbers.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.text.numbers.DecimalNumber.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.text.numbers.Integer.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.text.numbers.Variable.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.text.tex_mobject.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.text.tex_mobject.BulletedList.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.text.tex_mobject.MathTex.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.text.tex_mobject.SingleStringMathTex.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.text.tex_mobject.Tex.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.text.tex_mobject.Title.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.text.text_mobject.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.text.text_mobject.MarkupText.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.text.text_mobject.Paragraph.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.text.text_mobject.Text.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.three_d.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.three_d.polyhedra.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.three_d.polyhedra.ConvexHull3D.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.three_d.polyhedra.Dodecahedron.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.three_d.polyhedra.Icosahedron.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.three_d.polyhedra.Octahedron.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.three_d.polyhedra.Polyhedron.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.three_d.polyhedra.Tetrahedron.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.three_d.three_d_utils.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.three_d.three_dimensions.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.three_d.three_dimensions.Arrow3D.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.three_d.three_dimensions.Cone.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.three_d.three_dimensions.Cube.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.three_d.three_dimensions.Cylinder.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.three_d.three_dimensions.Dot3D.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.three_d.three_dimensions.Line3D.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.three_d.three_dimensions.Prism.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.three_d.three_dimensions.Sphere.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.three_d.three_dimensions.Surface.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.three_d.three_dimensions.ThreeDVMobject.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.three_d.three_dimensions.Torus.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.types.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.types.image_mobject.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.types.image_mobject.AbstractImageMobject.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.types.image_mobject.ImageMobject.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.types.image_mobject.ImageMobjectFromCamera.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.types.point_cloud_mobject.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.types.point_cloud_mobject.Mobject1D.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.types.point_cloud_mobject.Mobject2D.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.types.point_cloud_mobject.PGroup.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.types.point_cloud_mobject.PMobject.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.types.point_cloud_mobject.Point.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.types.point_cloud_mobject.PointCloudDot.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.types.vectorized_mobject.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.types.vectorized_mobject.CurvesAsSubmobjects.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.types.vectorized_mobject.DashedVMobject.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.types.vectorized_mobject.VDict.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.types.vectorized_mobject.VGroup.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.types.vectorized_mobject.VMobject.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.types.vectorized_mobject.VectorizedPoint.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.utils.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.value_tracker.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.value_tracker.ComplexValueTracker.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.value_tracker.ValueTracker.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.vector_field.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.vector_field.ArrowVectorField.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.vector_field.StreamLines.html
# [visited] https://docs.manim.community/en/stable/reference/manim.mobject.vector_field.VectorField.html
# [visited] https://docs.manim.community/en/stable/reference_index/scenes.html
# [visited] https://docs.manim.community/en/stable/reference/manim.scene.moving_camera_scene.html
# [visited] https://docs.manim.community/en/stable/reference/manim.scene.moving_camera_scene.MovingCameraScene.html
# [visited] https://docs.manim.community/en/stable/reference/manim.scene.section.html
# [visited] https://docs.manim.community/en/stable/reference/manim.scene.section.DefaultSectionType.html
# [visited] https://docs.manim.community/en/stable/reference/manim.scene.section.Section.html
# [visited] https://docs.manim.community/en/stable/reference/manim.scene.scene.html
# [visited] https://docs.manim.community/en/stable/reference/manim.scene.scene.RerunSceneHandler.html
# [visited] https://docs.manim.community/en/stable/reference/manim.scene.scene.Scene.html
# [visited] https://docs.manim.community/en/stable/reference/manim.scene.scene_file_writer.html
# [visited] https://docs.manim.community/en/stable/reference/manim.scene.scene_file_writer.SceneFileWriter.html
# [visited] https://docs.manim.community/en/stable/reference/manim.scene.three_d_scene.html
# [visited] https://docs.manim.community/en/stable/reference/manim.scene.three_d_scene.SpecialThreeDScene.html
# [visited] https://docs.manim.community/en/stable/reference/manim.scene.three_d_scene.ThreeDScene.html
# [visited] https://docs.manim.community/en/stable/reference/manim.scene.vector_space_scene.html
# [visited] https://docs.manim.community/en/stable/reference/manim.scene.vector_space_scene.LinearTransformationScene.html
# [visited] https://docs.manim.community/en/stable/reference/manim.scene.vector_space_scene.VectorScene.html
# [visited] https://docs.manim.community/en/stable/reference/manim.scene.zoomed_scene.html
# [visited] https://docs.manim.community/en/stable/reference/manim.scene.zoomed_scene.ZoomedScene.html
# [visited] https://docs.manim.community/en/stable/reference_index/utilities_misc.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.bezier.html
# [visited] https://docs.manim.community/en/stable/reference/manim.cli.html
# [visited] https://docs.manim.community/en/stable/reference/manim.cli.cfg.html
# [visited] https://docs.manim.community/en/stable/reference/manim.cli.checkhealth.html
# [visited] https://docs.manim.community/en/stable/reference/manim.cli.init.html
# [visited] https://docs.manim.community/en/stable/reference/manim.cli.plugins.html
# [visited] https://docs.manim.community/en/stable/reference/manim.cli.render.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.color.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.color.core.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.color.core.HSV.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.color.core.ManimColor.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.color.core.RGBA.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.color.manim_colors.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.color.AS2700.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.color.BS381.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.color.DVIPSNAMES.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.color.SVGNAMES.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.color.XKCD.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.color.X11.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.commands.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.commands.VideoMetadata.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.config_ops.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.config_ops.DictAsObject.html
# [visited] https://docs.manim.community/en/stable/reference/manim.constants.html
# [visited] https://docs.manim.community/en/stable/reference/manim.constants.CapStyleType.html
# [visited] https://docs.manim.community/en/stable/reference/manim.constants.LineJointType.html
# [visited] https://docs.manim.community/en/stable/reference/manim.constants.QualityDict.html
# [visited] https://docs.manim.community/en/stable/reference/manim.constants.RendererType.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.debug.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.deprecation.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.docbuild.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.docbuild.autoaliasattr_directive.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.docbuild.autoaliasattr_directive.AliasAttrDocumenter.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.docbuild.autocolor_directive.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.docbuild.autocolor_directive.ManimColorModuleDocumenter.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.docbuild.manim_directive.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.docbuild.manim_directive.ManimDirective.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.docbuild.manim_directive.SetupMetadata.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.docbuild.manim_directive.SkipManimNode.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.docbuild.module_parsing.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.hashing.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.images.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.ipython_magic.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.ipython_magic.ManimMagic.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.iterables.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.paths.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.rate_functions.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.rate_functions.RateFunction.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.simple_functions.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.simple_functions.Comparable.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.sounds.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.space_ops.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.testing.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.testing._frames_testers.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.testing._show_diff.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.testing._test_class_makers.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.testing._test_class_makers.DummySceneFileWriter.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.tex.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.tex.TexTemplate.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.tex_file_writing.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.tex_templates.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.tex_templates.TexFontTemplates.html
# [visited] https://docs.manim.community/en/stable/reference/manim.utils.tex_templates.TexTemplateLibrary.html
# [visited] https://docs.manim.community/en/stable/reference/manim.typing.html
# [visited] https://docs.manim.community/en/stable/plugins.html
# [visited] https://docs.manim.community/en/stable/changelog.html
# [visited] https://docs.manim.community/en/stable/changelog/0.19.0-changelog.html
# [visited] https://docs.manim.community/en/stable/changelog/0.18.0-changelog.html
# [visited] https://docs.manim.community/en/stable/changelog/0.17.3-changelog.html
# [visited] https://docs.manim.community/en/stable/changelog/0.17.2-changelog.html
# [visited] https://docs.manim.community/en/stable/changelog/0.17.1-changelog.html
# [visited] https://docs.manim.community/en/stable/changelog/0.17.0-changelog.html
# [visited] https://docs.manim.community/en/stable/changelog/0.16.0-changelog.html
# [visited] https://docs.manim.community/en/stable/changelog/0.15.2-changelog.html
# [visited] https://docs.manim.community/en/stable/changelog/0.15.1-changelog.html
# [visited] https://docs.manim.community/en/stable/changelog/0.15.0-changelog.html
# [visited] https://docs.manim.community/en/stable/changelog/0.14.0-changelog.html
# [visited] https://docs.manim.community/en/stable/changelog/0.13.1-changelog.html
# [visited] https://docs.manim.community/en/stable/changelog/0.13.0-changelog.html
# [visited] https://docs.manim.community/en/stable/changelog/0.12.0-changelog.html
# [visited] https://docs.manim.community/en/stable/changelog/0.11.0-changelog.html
# [visited] https://docs.manim.community/en/stable/changelog/0.10.0-changelog.html
# [visited] https://docs.manim.community/en/stable/changelog/0.9.0-changelog.html
# [visited] https://docs.manim.community/en/stable/changelog/0.8.0-changelog.html
# [visited] https://docs.manim.community/en/stable/changelog/0.7.0-changelog.html
# [visited] https://docs.manim.community/en/stable/changelog/0.6.0-changelog.html
# [visited] https://docs.manim.community/en/stable/changelog/0.5.0-changelog.html
# [visited] https://docs.manim.community/en/stable/changelog/0.4.0-changelog.html
# [visited] https://docs.manim.community/en/stable/changelog/0.3.0-changelog.html
# [visited] https://docs.manim.community/en/stable/changelog/0.2.0-changelog.html
# [visited] https://docs.manim.community/en/stable/changelog/0.1.1-changelog.html
# [visited] https://docs.manim.community/en/stable/changelog/0.1.0-changelog.html
# [visited] https://docs.manim.community/en/stable/contributing.html
# [visited] https://docs.manim.community/en/stable/contributing/development.html
# [visited] https://docs.manim.community/en/stable/contributing/docs.html
# [visited] https://docs.manim.community/en/stable/contributing/docs/admonitions.html
# [visited] https://docs.manim.community/en/stable/contributing/docs/docstrings.html
# [visited] https://docs.manim.community/en/stable/contributing/docs/examples.html
# [visited] https://docs.manim.community/en/stable/contributing/docs/references.html
# [visited] https://docs.manim.community/en/stable/contributing/docs/typings.html
# [visited] https://docs.manim.community/en/stable/contributing/docs/types.html
# [visited] https://docs.manim.community/en/stable/contributing/testing.html
# [visited] https://docs.manim.community/en/stable/contributing/performance.html
# [visited] https://docs.manim.community/en/stable/contributing/internationalization.html
# [visited] https://docs.manim.community/en/stable/conduct.html
# [visited] https://docs.manim.community/en/stable/index.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/animation/animation.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/animation/changing.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/animation/composition.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/animation/creation.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/animation/fading.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/animation/growing.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/animation/indication.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/animation/movement.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/animation/numbers.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/animation/rotation.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/animation/specialized.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/animation/speedmodifier.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/animation/transform.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/animation/transform_matching_parts.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/animation/updaters/mobject_update_utils.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/animation/updaters/update.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/camera/camera.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/camera/mapping_camera.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/camera/moving_camera.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/camera/multi_camera.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/camera/three_d_camera.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/_config.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/_config/utils.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/_config/logger_utils.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/mobject/frame.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/mobject/geometry/arc.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/mobject/geometry/boolean_ops.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/mobject/geometry/labeled.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/mobject/geometry/line.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/mobject/geometry/polygram.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/mobject/geometry/shape_matchers.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/mobject/geometry/tips.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/mobject/graph.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/mobject/graphing/coordinate_systems.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/mobject/graphing/functions.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/mobject/graphing/number_line.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/mobject/graphing/probability.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/mobject/graphing/scale.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/mobject/logo.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/mobject/matrix.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/mobject/mobject.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/mobject/svg/brace.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/mobject/svg/svg_mobject.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/mobject/table.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/mobject/text/code_mobject.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/mobject/text/numbers.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/mobject/text/tex_mobject.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/mobject/text/text_mobject.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/mobject/three_d/polyhedra.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/mobject/three_d/three_d_utils.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/mobject/three_d/three_dimensions.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/mobject/types/image_mobject.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/mobject/types/point_cloud_mobject.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/mobject/types/vectorized_mobject.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/mobject/utils.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/mobject/value_tracker.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/mobject/vector_field.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/scene/moving_camera_scene.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/scene/section.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/scene/scene.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/scene/scene_file_writer.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/scene/three_d_scene.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/scene/vector_space_scene.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/scene/zoomed_scene.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/utils/bezier.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/utils/color/core.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/utils/commands.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/utils/config_ops.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/constants.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/utils/debug.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/utils/deprecation.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/utils/docbuild/autoaliasattr_directive.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/utils/docbuild/autocolor_directive.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/utils/docbuild/manim_directive.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/utils/docbuild/module_parsing.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/utils/hashing.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/utils/images.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/utils/ipython_magic.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/utils/iterables.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/utils/paths.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/utils/rate_functions.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/utils/simple_functions.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/utils/sounds.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/utils/space_ops.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/utils/testing/_show_diff.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/utils/testing/_test_class_makers.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/utils/tex.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/utils/tex_file_writing.html
# [visited] https://docs.manim.community/en/stable/_modules/manim/utils/tex_templates.html
